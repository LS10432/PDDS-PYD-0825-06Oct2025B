# %% [markdown]
# <a href="https://colab.research.google.com/github/LS10432/PDDS-PYD-0825-06Oct2025B/blob/main/02/Titanic_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Loading the Data:
# * Load the Titanic dataset into a Pandas DataFrame.

# %%
# Import the pandas library and give it an alias 'pd'
import pandas as pd

# Read the Titanic dataset and load it into a DataFrame named 'df'
df = pd.read_csv('/content/titanic.csv')

# Display the entire DataFrame in the output
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Task 2: Initial Exploration:
# * Display the first 5 rows of the dataset to get an overview.
# * Provide basic information about the dataset using the info() method.

# %%
# Import the pandas library and give it an alias 'pd'
import pandas as pd

# Read the Titanic dataset and load it into a DataFrame named 'df'
df = pd.read_csv('/content/titanic.csv')

# Display the first 5 rows of the DataFrame in a visual, tabular format
display(df.head())

# Print a summary of the DataFrame including column names, number of non-null values, and data types
df.info()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %% [markdown]
# Task 3: Handling Missing Values:
# * Identify and count the number of missing values in each column.
# * Decide on an appropriate strategy for handling missing values in at least two columns and implement it.

# %%
# Import the pandas library and give it an alias 'pd'
import pandas as pd

# Read the Titanic dataset and load it into a DataFrame named 'df'
df = pd.read_csv('/content/titanic.csv')

# Code to count the number of rows in the DataFrame
num_rows = df.shape[0]
print(f"The number of rows in the DataFrame is: {num_rows}")
print("\n")

# Identify and count missing values in each column
print("Missing values before handling:")
print(df.isnull().sum())

# Handle missing values in 'Age' column by removing rows with missing value
df.dropna(subset=['Age'], inplace=True)

# Handle missing values in 'Embarked' column by removing rows with missing value
df.dropna(subset=['Embarked'], inplace=True)

print("\nMissing values after handling:")
print(df.isnull().sum())

# Code to count the number of rows in the DataFrame
num_rows = df.shape[0]
print("\n")
print(f"The number of rows in the DataFrame is: {num_rows}")
# Out:
# The number of rows in the DataFrame is: 891
#
#
# Missing values before handling:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Missing values after handling:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         0
# dtype: int64
#
#
# The number of rows in the DataFrame is: 712

# %% [markdown]
# Task 4: Descriptive Statistics:
# * Generate descriptive statistics for the numerical columns using the describe() method.

# %%
# Import the pandas library and give it an alias 'pd'
import pandas as pd

# Read the Titanic dataset and load it into a DataFrame named 'df'
df = pd.read_csv('/content/titanic.csv')

# Code to count the number of rows in the DataFrame
num_rows = df.shape[0]
print(f"The number of rows in the DataFrame is: {num_rows}")
print("\n")

# Identify and count missing values in each column
print("Missing values before handling:")
print(df.isnull().sum())

# Handle missing values in 'Age' column by removing rows with missing value
df.dropna(subset=['Age'], inplace=True)

# Handle missing values in 'Embarked' column by removing rows with missing value
df.dropna(subset=['Embarked'], inplace=True)

print("\nMissing values after handling:")
print(df.isnull().sum())

# Code to count the number of rows in the DataFrame
num_rows = df.shape[0]
print("\n")
print(f"The number of rows in the DataFrame is: {num_rows}")
print("\n")

# Generate descriptive statistics for numerical columns
display(df.describe())
# Out:
# The number of rows in the DataFrame is: 891
#
#
# Missing values before handling:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Missing values after handling:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         0
# dtype: int64
#
#
# The number of rows in the DataFrame is: 712
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   712.000000  712.000000  712.000000  712.000000  712.000000
# mean    448.589888    0.404494    2.240169   29.642093    0.514045
# std     258.683191    0.491139    0.836854   14.492933    0.930692
# ...

# %% [markdown]
# Task 5: Unique Values:
# * List unique values in the 'Pclass' column.
# * Count the occurrences of each unique value in the 'Embarked' column.

# %%
# Import the pandas library and give it an alias 'pd'
import pandas as pd

# Read the Titanic dataset and load it into a DataFrame named 'df'
df = pd.read_csv('/content/titanic.csv')

# Code to count the number of rows in the DataFrame
num_rows = df.shape[0]
print(f"The number of rows in the DataFrame is: {num_rows}")
print("\n")

# Identify and count missing values in each column
print("Missing values before handling:")
print(df.isnull().sum())

# Handle missing values in 'Age' column by removing rows with missing value
df.dropna(subset=['Age'], inplace=True)

# Handle missing values in 'Embarked' column by removing rows with missing value
df.dropna(subset=['Embarked'], inplace=True)

print("\nMissing values after handling:")
print(df.isnull().sum())

# Code to count the number of rows in the DataFrame
num_rows = df.shape[0]
print("\n")
print(f"The number of rows in the DataFrame is: {num_rows}")
print("\n")

# Generate descriptive statistics for numerical columns
display(df.describe())

# List unique values in the 'Pclass' column
print("Unique values in 'Pclass' column:")
display(df['Pclass'].unique())

# Show rows for Pclass 1
print("Rows for Pclass 1:")
#display(df[df['Pclass'] == 1].head())

# Show rows for Pclass 2
print("\nRows for Pclass 2:")
#display(df[df['Pclass'] == 2].head())

# Show rows for Pclass 3
print("\nRows for Pclass 3:")
#display(df[df['Pclass'] == 3].head())

# Count the occurrences of each unique value in the 'Embarked' column
print("\nOccurrences of unique values in 'Embarked' column:")
display(df['Embarked'].value_counts())
# Out:
# The number of rows in the DataFrame is: 891
#
#
# Missing values before handling:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Missing values after handling:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          529
# Embarked         0
# dtype: int64
#
#
# The number of rows in the DataFrame is: 712
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   712.000000  712.000000  712.000000  712.000000  712.000000
# mean    448.589888    0.404494    2.240169   29.642093    0.514045
# std     258.683191    0.491139    0.836854   14.492933    0.930692
# ...

# %% [markdown]
# Task 6: Data Manipulation:
# * Create a new column named 'FamilySize' that represents the sum of 'SibSp' and 'Parch'.
# * Drop the 'Cabin' column from the dataset.

# %%
# Create a new column named 'FamilySize' that represents the sum of 'SibSp' and 'Parch'
df['FamilySize'] = df['SibSp'] + df['Parch']

# Drop the 'Cabin' column from the dataset
df = df.drop('Cabin', axis=1)

# Display the first few rows to show the changes
display(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  FamilySize
# 0      0         A/5 21171   7.2500        S           1
# 1      0          PC 17599  71.2833        C           1
# 2      0  STON/O2. 3101282   7.9250        S           0
# 3      0            113803  53.1000        S           1
# ...

# %% [markdown]
# Task 7: Filtering and Sorting:
# * Create a new DataFrame containing only passengers with an age greater than 30.
# * Sort the DataFrame by 'Fare' in descending order.

# %%
# Create a new DataFrame containing only passengers with an age greater than 30
df_age_over_30 = df[df['Age'] > 30]

# Sort the DataFrame by 'Fare' in descending order
df_sorted_by_fare = df_age_over_30.sort_values(by='Fare', ascending=False)

# Display the first few rows of the sorted DataFrame
display(df_sorted_by_fare.head())
# Out:
#      PassengerId  Survived  Pclass  \
# 679          680         1       1
# 737          738         1       1
# 258          259         1       1
# 438          439         0       1
# 299          300         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 679               Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 737                           Lesurer, Mr. Gustave J    male  35.0      0
# 258                                 Ward, Miss. Anna  female  35.0      0
# 438                                Fortune, Mr. Mark    male  64.0      1
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
#
#      Parch    Ticket      Fare Embarked  FamilySize
# 679      1  PC 17755  512.3292        C           1
# 737      0  PC 17755  512.3292        C           0
# 258      0  PC 17755  512.3292        C           0
# 438      4     19950  263.0000        S           5
# ...

# %% [markdown]
# Task 8: Data Analysis:
# * Calculate the survival rate for different passenger classes ('Pclass').
# * Identify and display the passenger with the highest 'Fare'.

# %%
# Calculate the survival rate for different passenger classes ('Pclass')
survival_rate_by_pclass = df.groupby('Pclass')['Survived'].mean()
print("Survival rate by Passenger Class:")
display(survival_rate_by_pclass)

# Identify and display the passenger with the highest 'Fare'
passenger_highest_fare = df.loc[df['Fare'].idxmax()]
print("\nPassenger with the highest Fare:")
display(passenger_highest_fare)
# Out:
# Survival rate by Passenger Class:
# Pclass
# 1    0.652174
# 2    0.479769
# 3    0.239437
# Name: Survived, dtype: float64
# Passenger with the highest Fare:
# PassengerId                 259
# Survived                      1
# Pclass                        1
# Name           Ward, Miss. Anna
# Sex                      female
# Age                        35.0
# SibSp                         0
# Parch                         0
# Ticket                 PC 17755
# Fare                   512.3292
# Embarked                      C
# FamilySize                    0
# Name: 258, dtype: object
