# %% [markdown]
# <a href="https://colab.research.google.com/github/LS10432/PDDS-PYD-0825-06Oct2025B/blob/main/Project/PI/PI02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Activity 1: Data Loading and Exploration
#
# Initializing the analysis by loading and exploring the dataset, ensuring data integrity and format consistency for accurate downstream analysis.

# %% [markdown]
# ## Load data
#
# 1. Load the COVID-19 DataFrame using pandas from the provided dataset files.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define the local path and the URL for the covid dataset
local_path = '/content/owid-covid-data.csv'
covid_url = 'https://lms.educlaas.com/assets/courseware/v1/e206258dd748e86b8bb35fc039e90fa8/asset-v1:EduCLaSS+PYD+PDDS-PYD-0825-06Oct2025B+type@asset+block/owid-covid-data.csv'

try:
    # Try to read the Titanic dataset from the local path
    df = pd.read_csv(local_path)
    print(f"Successfully loaded data from {local_path}")
    print("\n")
except FileNotFoundError:
    # If the local file is not found, read the dataset from the URL
    df = pd.read_csv(covid_url)
    print(f"Local file not found. Loading data from {covid_url}")
    print("\n")

print(f"Total number of columns: {df.shape[1]}")
print(f"Total number of rows: {df.shape[0]}")
# Out:
# Successfully loaded data from /content/owid-covid-data.csv
#
#
# Total number of columns: 67
# Total number of rows: 358838

# %% [markdown]
# ## Display head and tail
#
# 2. Display the first 5 and last 5 rows of the DataFrame.

# %%
# Print a newline followed by a separator line
print("\n" + "="*60)
print("Display the first 5 rows of the DataFrame.")
# Print a newline followed by a separator line
print("\n" + "="*60)
# Print the first 5 rows of the DataFrame
display(df.head())

# Print a newline followed by a separator line
print("\n" + "="*60)
print("Display the last 5 rows of the DataFrame.")
# Print a newline followed by a separator line
print("\n" + "="*60)
# Print the last 5 rows of the DataFrame
display(df.tail())
# Out:
# ...
# Display the first 5 rows of the DataFrame.
#
# ...
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
# ...

# %% [markdown]
# ## Check missing values
#
# 3. Check for missing values in the dataset and decide on a strategy to handle them.

# %%
print("\n" + "="*60)
print("Identify columns with missing values:\n")

# Identify and count missing values in each column
print(df.isnull().sum())
# Print a newline followed by a separator line
print("\n" + "="*60)

# Calculate columns no missing values
missing_cols = df.isnull().sum() != 0

# Display columns no missing values
print(f"Number of columns with no missing values: {len(missing_cols) - missing_cols.sum()}")
print("Column Names with no missing values:")
display(missing_cols[missing_cols == False].index.tolist())

# Print columns missing values
print("\n" + "="*60)
print(f"Number of columns with missing values: {missing_cols.sum()}")

# Calculate percentage of columns with more than 90% missing values.
missing_values_percentage = df.isnull().mean() * 100
columns_to_drop = missing_values_percentage[missing_values_percentage > 90].index.tolist()

# Display columns with more than 90% missing values
print(f"Number of columns with more than 90% missing values: {len(columns_to_drop)}")
print("Column Names with more than 90% missing values:")
print(columns_to_drop)
print("\n" + "="*60)
# Out:
# ...
# Identify columns with missing values:
#
# iso_code                                        0
# continent                                   17108
# location                                        0
# date                                            0
# total_cases                                 38210
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       346627
# excess_mortality_cumulative                346627
# excess_mortality                           346627
# excess_mortality_cumulative_per_million    346627
# Length: 67, dtype: int64
#
# ...
# Number of columns with no missing values: 4
# Column Names with no missing values:
# ['iso_code', 'location', 'date', 'population']
# ...
# Number of columns with missing values: 63
# Number of columns with more than 90% missing values: 8
# Column Names with more than 90% missing values:
# ...

# %% [markdown]
# ## Remove columns
#
# 4. Remove the columns with more than 90% of missing values.

# %%
print("\n"+"="*60)
# Print number of columns to be dropped
print(f"Number of columns to be dropped: {len(columns_to_drop)}")
print("Column Names to be dropped:")
print(columns_to_drop)
print("\n"+"="*60)

# Remove columns with more than 90% missing values
df = df.drop(columns=columns_to_drop)

# Print a newline
print("Display the columns info after drop:")
print("\n")

# Display the columns after drop
print(df.info())
#display(df.columns)

# Print number of columns remaining
print("\n"+"="*60)
print(f"Number of columns after removal: {df.shape[1]}")
print("\n"+"="*60)
# Out:
# ...
# Number of columns to be dropped: 8
# Column Names to be dropped:
# ['weekly_icu_admissions', 'weekly_icu_admissions_per_million', 'weekly_hosp_admissions', 'weekly_hosp_admissions_per_million', 'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative', 'excess_mortality', 'excess_mortality_cumulative_per_million']
#
# ...
# Display the columns info after drop:
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358838 entries, 0 to 358837
# Data columns (total 59 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    358838 non-null  object
#  1   continent                                   341730 non-null  object
#  2   location                                    358838 non-null  object
#  3   date                                        358838 non-null  object
# ...

# %% [markdown]
# ## Convert date column
#
# 5. Convert the 'date' column to the datetime data type.

# %%
# Print a newline followed by a separator line
print("\n" + "="*60)
# Display the data type of the 'date' column
print(f"Data type of 'date' column before conversion: {df['date'].dtype}")

# Print a newline followed by a separator line
print("\n" + "="*60)
print("Column info before conversion:")
print("\n")
# Display summary of the DataFrame
df.info()

# Convert the 'date' column from object type to datetime type
df['date'] = pd.to_datetime(df['date'])

# Print a newline followed by a separator line
print("\n" + "="*60)
# Display the updated data type of the 'date' column
print(f"Data type of 'date' column after conversion: {df['date'].dtype}")

# Print a newline followed by a separator line
print("\n" + "="*60)
print("Column info after conversion:")
print("\n")
# Display summary of the DataFrame
df.info()
# Out:
# ...
# Data type of 'date' column before conversion: object
#
# ...
# Column info before conversion:
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358838 entries, 0 to 358837
# Data columns (total 59 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    358838 non-null  object
#  1   continent                                   341730 non-null  object
#  2   location                                    358838 non-null  object
#  3   date                                        358838 non-null  object
#  4   total_cases                                 320628 non-null  float64
#  5   new_cases                                   349032 non-null  float64
#  6   new_cases_smoothed                          347773 non-null  float64
#  7   total_deaths                                299086 non-null  float64
# ...

# %% [markdown]
# # Activity 2: Data Cleaning and Feature Engineering
# Data Cleaning and Feature Engineering Enhancing data relevance and structure, enabling focused analysis on key COVID-19 indicators and demographic factors.

# %% [markdown]
# ## Impute missing values
# 1. Impute missing values in the dataset columns

# %% [markdown]
# **Reasoning for imputation methods**
# * Mean is used for numerical columns because it represents the central tendency of the data and is a common method for imputing missing numerical values when the data is not heavily skewed.
# * Mode is used for categorical columns because it represents the most
# frequent category, which is a suitable way to fill missing values in discrete data where the concept of mean is not applicable.

# %%
print("\n" + "="*60)

# Identify and count missing values in each column
missing_values_per_column = df.isnull().sum()

# Calculate columns with missing values
missing_cols_count = missing_values_per_column[missing_values_per_column != 0].count()

# Calculate numerical and non-numerical columns with missing values
numerical_cols_with_missing = df.select_dtypes(include=['float64', 'int64']).columns[df.select_dtypes(include=['float64', 'int64']).isnull().any()]
categorical_cols_with_missing = df.select_dtypes(include=['object']).columns[df.select_dtypes(include=['object']).isnull().any()]

# Display number of columns missing values and numerical and non-numerical columns with missing values
print(f"Total number of columns: {df.shape[1]}")
print(f"Number of columns with missing values: {missing_cols_count}")
print(f"Number of numerical columns with missing values: {len(numerical_cols_with_missing)}")
print(f"Number of non-numerical columns with missing values: {len(categorical_cols_with_missing)}")
print("\n" + "="*60)

# Select numerical columns
print(f"Number of numerical columns with missing values: {len(numerical_cols_with_missing)}")
#print("Use the built-in mean() function to replace missing values in numerical columns. Mean is a common method for imputing missing numerical values when the data is not heavily skewed, as it represents the central tendency of the data.")

# Impute missing values in numerical columns using the mean
for col in numerical_cols_with_missing:
  mean_val = df[col].mean()
  df[col] = df[col].fillna(mean_val)

# Print the number of remaining missing values per column fter numerical imputation
print("\nNumber of remaining missing values per column after numerical imputation:")
print(df.isnull().sum())
print("\n" + "="*60)

# Select categorical columns
print(f"Number of non-numerical columns with missing values: {len(categorical_cols_with_missing)}")
#print("Use the built-in mode() function to replace missing values in non-numerical columns. Mode is suitable for categorical columns as it represents the most frequent category, making it ideal for filling missing values in discrete data where mean is not applicable.")

# Impute missing values in categorical columns using the mode
for col in categorical_cols_with_missing:
  mode_val = df[col].mode()[0] # mode() can return multiple values, take the first
  df[col] = df[col].fillna(mode_val)

# Print the number of remaining missing values per column
print("\nNumber of remaining missing values per column after non-numerical imputation:")
print(df.isnull().sum())

print("\n" + "="*60)
# Out:
# ...
# Total number of columns: 59
# Number of columns with missing values: 55
# Number of numerical columns with missing values: 53
# Number of non-numerical columns with missing values: 2
#
# ...
# Number of numerical columns with missing values: 53
#
# Number of remaining missing values per column after numerical imputation:
# iso_code                                           0
# continent                                      17108
# location                                           0
# date                                               0
# total_cases                                        0
# new_cases                                          0
# new_cases_smoothed                                 0
# total_deaths                                       0
# new_deaths                                         0
# new_deaths_smoothed                                0
# total_cases_per_million                            0
# new_cases_per_million                              0
# ...

# %% [markdown]
# ## Remove duplicate rows
# 2. Remove duplicate rows from the DataFrame.

# %%
# Get the number of rows before removing duplicates
rows_before = df.shape[0]
print(f"Number of rows before removing duplicates: {rows_before}")

# Count the number of duplicate rows
duplicate_rows = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")

# Remove duplicate rows
df = df.drop_duplicates()

# Get the number of rows after removing duplicates
rows_after = df.shape[0]
print(f"Number of rows after removing duplicates: {rows_after}")
# Out:
# Number of rows before removing duplicates: 358838
# Number of duplicate rows: 0
# Number of rows after removing duplicates: 358838

# %% [markdown]
# ## Create new features
# 3. Create new features if needed (e.g., extract year and month from the 'date' column).

# %% [markdown]
# **Reasoning for extracting year and month**
#
# Extracting year and month from the date column is crucial for time-series analysis. It allows for grouping data by specific time periods, identifying seasonal trends, and comparing metrics across different years and months. This granularity in time data is essential for understanding patterns and changes in the COVID-19 data over time.

# %%
# Extract year and month from the 'date' column
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# Display the head of the DataFrame to show the new columns
print("\n" + "="*60)
print("Display the first 5 rows of the DataFrame with 'year' and 'month' columns.")
print("\n" + "="*60)
display(df.head())

print("\n" + "="*60)
df.info()
# Out:
# ...
# Display the first 5 rows of the DataFrame with 'year' and 'month' columns.
#
# ...
#   iso_code continent     location       date   total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-01-03  6.862419e+06        0.0
# 1      AFG      Asia  Afghanistan 2020-01-04  6.862419e+06        0.0
# 2      AFG      Asia  Afghanistan 2020-01-05  6.862419e+06        0.0
# 3      AFG      Asia  Afghanistan 2020-01-06  6.862419e+06        0.0
# 4      AFG      Asia  Afghanistan 2020-01-07  6.862419e+06        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0         9409.255662  86954.368292         0.0            83.807025  ...
# 1         9409.255662  86954.368292         0.0            83.807025  ...
# 2         9409.255662  86954.368292         0.0            83.807025  ...
# 3         9409.255662  86954.368292         0.0            83.807025  ...
# 4         9409.255662  86954.368292         0.0            83.807025  ...
#
# ...

# %% [markdown]
# ## Explore unique countries
# 4. Explore unique countries in the dataset and count the total number of countries.

# %%
# Get unique countries from the 'location' column
unique_countries = df['location'].unique()

# Count the number of unique countries
num_unique_countries = len(unique_countries)

print("\n" + "="*60)
# Print the total count of unique countries
print(f"Total number of unique countries: {num_unique_countries}")
print("\n" + "="*60)

# Display the list of unique countries
print("\nList of unique countries:")
print(unique_countries)
# Out:
# ...
# Total number of unique countries: 255
#
# ...
#
# List of unique countries:
# ['Afghanistan' 'Africa' 'Albania' 'Algeria' 'American Samoa' 'Andorra'
#  'Angola' 'Anguilla' 'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba'
#  'Asia' 'Australia' 'Austria' 'Azerbaijan' 'Bahamas' 'Bahrain'
#  'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin' 'Bermuda'
#  'Bhutan' 'Bolivia' 'Bonaire Sint Eustatius and Saba'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cambodia' 'Cameroon'
#  'Canada' 'Cape Verde' 'Cayman Islands' 'Central African Republic' 'Chad'
#  'Chile' 'China' 'Colombia' 'Comoros' 'Congo' 'Cook Islands' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia'
#  'Democratic Republic of Congo' 'Denmark' 'Djibouti' 'Dominica'
#  'Dominican Republic' 'Ecuador' 'Egypt' 'El Salvador' 'England'
#  'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini' 'Ethiopia' 'Europe'
# ...

# %% [markdown]
# # Activity 3: Global COVID-19 Overview
# Worldwide COVID-19 Overview Providing a global and temporal perspective on COVID-19, identifying patterns and correlations crucial for strategic decision-making.

# %% [markdown]
# ## Visualize total cases and deaths by continent
# 1. Visualize the WHO Regions (Continent column in dataset) with total COVID-19 cases and total deaths by using bar plots.

# %% [markdown]
# ### Prepare data for visualization
# Aggregate the data by continent to calculate the total cases and deaths for each continent.

# %%
df_continent = df.groupby('continent')[['total_cases', 'total_deaths']].sum().reset_index()
display(df_continent)
# Out:
#        continent   total_cases  total_deaths
# 0         Africa  1.729765e+12  2.077518e+10
# 1           Asia  2.447360e+11  2.525415e+09
# 2         Europe  2.278041e+11  2.778771e+09
# 3  North America  1.157474e+11  2.125727e+09
# 4        Oceania  8.185264e+10  1.477310e+09
# 5  South America  6.259182e+10  1.520126e+09

# %%
# Bar plot for total cases by continent
plt.figure(figsize=(10, 5))
plt.bar(df_continent['continent'], df_continent['total_cases'], color='blue')
plt.title('Total COVID-19 Cases by Continent')
plt.xlabel('Continent')
plt.ylabel('Total Cases')
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# Bar plot for total deaths by continent
plt.figure(figsize=(10, 5))
plt.bar(df_continent['continent'], df_continent['total_deaths'], color='red')
plt.title('Total COVID-19 Deaths by Continent')
plt.xlabel('Continent')
plt.ylabel('Total Deaths')
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize worldwide monthly trend
# 2. Explore the world wide monthly trend of  COVID-19 cases using a line plot.

# %% [markdown]
# ### Prepare data for worldwide monthly trend
# Aggregate the data by year and month to calculate the total worldwide COVID-19 cases for each month.

# %%
df_monthly_cases = df.groupby(['year', 'month'])['total_cases'].sum().reset_index()
display(df_monthly_cases.head())
# Out:
#    year  month   total_cases
# 0  2020      1  4.623913e+10
# 1  2020      2  4.130453e+10
# 2  2020      3  2.043716e+10
# 3  2020      4  6.876284e+09
# 4  2020      5  6.421527e+09

# %%
# Create a combined year-month string for the x-axis
df_monthly_cases['year_month'] = df_monthly_cases['year'].astype(str) + '-' + df_monthly_cases['month'].astype(str)

# Create a line plot
plt.figure(figsize=(15, 7))
plt.plot(df_monthly_cases['year_month'], df_monthly_cases['total_cases'])
plt.title('Worldwide Monthly Trend of COVID-19 Cases')
plt.xlabel('Month')
plt.ylabel('Total Cases')
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels overlapping
plt.show()

# %% [markdown]
# ## Visualize correlation
# 3. Investigate the correlation between total cases and total deaths using a heatmap.

# %% [markdown]
# ### Prepare data for correlation analysis
# Select the relevant columns (`total_cases` and `total_deaths`) and calculate the correlation matrix.

# %%
correlation_matrix = df[['total_cases', 'total_deaths']].corr()
display(correlation_matrix)
# Out:
#               total_cases  total_deaths
# total_cases      1.000000      0.937965
# total_deaths     0.937965      1.000000

# %%
# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Total Cases and Total Deaths')
plt.show()

# %% [markdown]
# ## Visualize total cases over time for a single location
# 4. Analyze how total cases have evolved over time for a specific location (e.g., Singapore).

# %% [markdown]
# ### Prepare data for single location analysis
# Filter the data to include only the data for the specified location (e.g., Singapore).

# %%
df_singapore = df[df['location'] == 'Singapore'].copy()
display(df_singapore.head())
# Out:
#        iso_code continent   location       date   total_cases  new_cases  \
# 288102      SGP      Asia  Singapore 2020-01-03  6.862419e+06        0.0
# 288103      SGP      Asia  Singapore 2020-01-04  6.862419e+06        0.0
# 288104      SGP      Asia  Singapore 2020-01-05  6.862419e+06        0.0
# 288105      SGP      Asia  Singapore 2020-01-06  6.862419e+06        0.0
# 288106      SGP      Asia  Singapore 2020-01-07  6.862419e+06        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 288102         9409.255662  86954.368292         0.0            83.807025
# 288103         9409.255662  86954.368292         0.0            83.807025
# 288104         9409.255662  86954.368292         0.0            83.807025
# 288105         9409.255662  86954.368292         0.0            83.807025
# 288106         9409.255662  86954.368292         0.0            83.807025
#
#         ...  diabetes_prevalence  female_smokers  male_smokers  \
# ...

# %%
# Create a line plot for total cases over time in Singapore
plt.figure(figsize=(15, 7))
plt.plot(df_singapore['date'], df_singapore['total_cases'])
plt.title('Total COVID-19 Cases Over Time in Singapore')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# #Activity 4: Regional COVID-19 dynamics and patterns
# Regional Analysis Unveiling regional nuances in COVID-19 dynamics and identifying patterns in case distribution and fatality across time and continents.

# %% [markdown]
# ## Visualize monthly new cases by continent
# 1. Create a grouped bar chart to visualize new cases by continent and month.

# %% [markdown]
# ### Prepare data for monthly new cases by continent
# Group the data by continent and month, summing the `new_cases` for each group.

# %%
df_monthly_new_cases_continent = df.groupby(['continent', 'year', 'month'])['new_cases'].sum().reset_index()
display(df_monthly_new_cases_continent.head())
display(df_monthly_new_cases_continent.tail())
# Out:
#   continent  year  month  new_cases
# 0    Africa  2020      1    29584.0
# 1    Africa  2020      2   225058.0
# 2    Africa  2020      3  2441266.0
# 3    Africa  2020      4  7170448.0
# 4    Africa  2020      5  8945605.0
#          continent  year  month     new_cases
# 277  South America  2023      7  77752.000000
# 278  South America  2023      8  15590.000000
# 279  South America  2023      9  11325.000000
# 280  South America  2023     10   4485.000000
# 281  South America  2023     11  38357.022531

# %%
# Create a combined year-month string for the x-axis
df_monthly_new_cases_continent['year_month'] = df_monthly_new_cases_continent['year'].astype(str) + '-' + df_monthly_new_cases_continent['month'].astype(str)

# Create a grouped bar chart to visualize the new cases by continent and month
plt.figure(figsize=(16, 7))
sns.barplot(data=df_monthly_new_cases_continent, x='year_month', y='new_cases', hue='continent')
plt.title('Monthly New Cases by Continent')
plt.xlabel('Year-Month')
plt.ylabel('New Cases')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize total cases distribution by year
# 2. Visualize the distribution of total COVID-19 cases by year using a box plot.

# %% [markdown]
# ### Prepare data for total cases distribution by year
# Using the year column extracted from 'date' column in datetime format.

# %%
# Create a box plot to visualize the total cases by Year
plt.figure(figsize=(12, 9))
sns.boxplot(data=df, x='year', y='total_cases')
plt.title('Distribution of Total COVID-19 Cases by Year')
plt.xlabel('Year')
plt.ylabel('Total Cases')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ## Visualize total deaths by continent
# 3. Compare total deaths across different continents using a bar plot.

# %% [markdown]
# ### Prepare data for total deaths by continent
# Group the data by continent, summing the `total_deaths` for each continent.

# %%
df_continent_deaths = df.groupby('continent')['total_deaths'].sum().reset_index()
display(df_continent_deaths)
# Out:
#        continent  total_deaths
# 0         Africa  2.077518e+10
# 1           Asia  2.525415e+09
# 2         Europe  2.778771e+09
# 3  North America  2.125727e+09
# 4        Oceania  1.477310e+09
# 5  South America  1.520126e+09

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_continent_deaths, x='continent', y='total_deaths')
plt.title('Total COVID-19 Deaths by Continent')
plt.xlabel('Continent')
plt.ylabel('Total Deaths')
plt.show()

# %% [markdown]
# ## Visualize total cases by month
# 4. Analyze the total cases on a month-by-month basis using a bar plot.

# %% [markdown]
# ### Prepare data for total cases by month
# Group the data by month, summing the `total_cases` for each month.

# %%
df_monthly_cases = df.groupby(['year', 'month'])['total_cases'].sum().reset_index()
display(df_monthly_cases)
# Out:
#     year  month   total_cases
# 0   2020      1  4.623913e+10
# 1   2020      2  4.130453e+10
# 2   2020      3  2.043716e+10
# 3   2020      4  6.876284e+09
# 4   2020      5  6.421527e+09
# 5   2020      6  6.539742e+09
# 6   2020      7  7.459128e+09
# 7   2020      8  8.439781e+09
# 8   2020      9  9.197913e+09
# 9   2020     10  1.034004e+10
# 10  2020     11  1.145915e+10
# 11  2020     12  1.396563e+10
# 12  2021      1  1.665704e+10
# 13  2021      2  1.705498e+10
# 14  2021      3  2.052047e+10
# 15  2021      4  2.217414e+10
# 16  2021      5  2.583687e+10
# 17  2021      6  2.679480e+10
# 18  2021      7  2.913625e+10
# 19  2021      8  3.140743e+10
# 20  2021      9  3.243645e+10
# 21  2021     10  3.517075e+10
# 22  2021     11  3.564728e+10
# 23  2021     12  3.936330e+10
# 24  2022      1  4.672005e+10
# 25  2022      2  5.206098e+10
# 26  2022      3  6.424131e+10
# 27  2022      4  6.700879e+10
# 28  2022      5  7.161105e+10
# 29  2022      6  7.117556e+10
# ...

# %%
# Create a combined year-month string for the x-axis
df_monthly_cases['year_month'] = df_monthly_cases['year'].astype(str) + '-' + df_monthly_cases['month'].astype(str)

# Create a bar plot
plt.figure(figsize=(18, 7))
sns.barplot(data=df_monthly_cases, x='year_month', y='total_cases')
plt.title('Total COVID-19 Cases by Month')
plt.xlabel('Month')
plt.ylabel('Total Cases')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# #Activity 5: Time Series Analysis
# Time Series Analysis Capturing the daily dynamics of COVID-19, assessing the impact of vaccination, and monitoring testing metrics for a comprehensive global overview.

# %% [markdown]
# ## Visualize daily trends
# 1. Explore the daily trend of new cases and new deaths globally using line plots.

# %% [markdown]
# ### Prepare data for global analysis
# Group the data by date and sum the 'new_cases' and 'new_deaths' to get daily global totals.

# %%
global_daily_cases_deaths = df.groupby('date')[['new_cases', 'new_deaths']].sum().reset_index()
display(global_daily_cases_deaths.head())
# Out:
#         date     new_cases  new_deaths
# 0 2020-01-01  18751.011265  167.031072
# 1 2020-01-02  18751.011265  167.031072
# 2 2020-01-03      0.000000    0.000000
# 3 2020-01-04     14.000000    0.000000
# 4 2020-01-05   9375.505633   15.000000

# %%
# Create a dual-axis plot for better comparison
fig, ax1 = plt.subplots(figsize=(15,7))

# Plot new cases (left axis)
sns.lineplot(data=global_daily_cases_deaths, x='date', y='new_cases', color='blue', ax=ax1, label='New Cases')
ax1.set_xlabel('Date')
ax1.set_ylabel('New Cases', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create second axis for new deaths
ax2 = ax1.twinx()
sns.lineplot(data=global_daily_cases_deaths, x='date', y='new_deaths', color='red', ax=ax2, label='New Deaths')
ax2.set_ylabel('New Deaths', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Adjust the y-axis limits for new_deaths to be closer to new_cases
# This will make the new_deaths trend appear very flat due to the difference in magnitude.
ax2.set_ylim(ax1.get_ylim()[0]/20, ax1.get_ylim()[1]/20)

# Add title and legend
plt.title('Global Daily Trend of New COVID-19 Cases and Deaths')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)

plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Calculate and visualize daily averages
# 2. Calculate and visualize the daily average new cases and deaths globally.

# %%
daily_avg = df.groupby('date')[['new_cases', 'new_deaths']].mean().reset_index()
display(daily_avg.head())
display(daily_avg.tail())
# Out:
#         date    new_cases  new_deaths
# 0 2020-01-01  9375.505633   83.515536
# 1 2020-01-02  9375.505633   83.515536
# 2 2020-01-03     0.000000    0.000000
# 3 2020-01-04     0.056911    0.000000
# 4 2020-01-05    38.111812    0.060976
#            date    new_cases  new_deaths
# 1425 2023-11-26  9375.505633   83.515536
# 1426 2023-11-27  9375.505633   83.515536
# 1427 2023-11-28  9375.505633   83.515536
# 1428 2023-11-29  9375.505633   83.515536
# 1429 2023-11-30  9375.505633   83.515536

# %%
# Create a dual-axis plot for better comparison
fig, ax1 = plt.subplots(figsize=(15,7))

# Plot total cases (left axis)
sns.lineplot(data=daily_avg, x='date', y='new_cases', color='blue', ax=ax1, label='Average New Cases')
ax1.set_xlabel('Date')
ax1.set_ylabel('Average New Cases', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create second axis for positive rate
ax2 = ax1.twinx()
sns.lineplot(data=daily_avg, x='date', y='new_deaths', color='red', ax=ax2, label='Average New Deaths')
ax2.set_ylabel('Average New Deaths', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add title and legend
plt.title('Global Daily Average of New COVID-19 Cases and Deaths')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)

plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize vaccination trend
# 3. Explore the trend of vaccination coverage over time globally.

# %% [markdown]
# ### Prepare data for vaccination analysis
# Group the data by date and sum the relevant vaccination columns to get daily global vaccination totals.

# %%
vaccination_cols = ['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated']
global_daily_vaccinations = df.groupby('date')[vaccination_cols].sum().reset_index()
display(global_daily_vaccinations.head())
# Out:
#         date  total_vaccinations  people_vaccinated  people_fully_vaccinated
# 0 2020-01-01        9.243474e+08       4.101988e+08             3.744132e+08
# 1 2020-01-02        9.243474e+08       4.101988e+08             3.744132e+08
# 2 2020-01-03        1.136947e+11       5.045445e+10             4.605283e+10
# 3 2020-01-04        1.136947e+11       5.045445e+10             4.605283e+10
# 4 2020-01-05        1.136947e+11       5.045445e+10             4.605283e+10

# %%
# Create a line plot
plt.figure(figsize=(15, 7))
sns.lineplot(data=global_daily_vaccinations, x='date', y='total_vaccinations', color='blue', linewidth=2, label='Total Vaccinations')
sns.lineplot(data=global_daily_vaccinations, x='date', y='people_vaccinated', color='green', linewidth=2, label='People Vaccinated')
sns.lineplot(data=global_daily_vaccinations, x='date', y='people_fully_vaccinated', color='red', linewidth=2, label='People Fully Vaccinated')
plt.title('Global Vaccination Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Vaccinations')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyze and visualize testing metrics
# 4. Analyze the total tests and positive rate over time globally.

# %% [markdown]
# ### Prepare data for testing analysis
# Group the data by date and sum the relevant testing columns to get daily global testing totals.

# %%
testing_cols = ['total_tests', 'positive_rate']
global_daily_testing = df.groupby('date')[testing_cols].sum().reset_index()
display(global_daily_testing.head())
# Out:
#         date   total_tests  positive_rate
# 0 2020-01-01  2.900000e+01       0.196325
# 1 2020-01-02  1.960000e+02       0.196325
# 2 2020-01-03  5.149516e+09      24.147976
# 3 2020-01-04  5.128412e+09      24.147976
# 4 2020-01-05  5.128412e+09      24.147976

# %%
# Create a dual-axis plot for better comparison
fig, ax1 = plt.subplots(figsize=(15,7))

# Plot total tests (left axis)
sns.lineplot(data=global_daily_testing, x='date', y='total_tests', color='blue', ax=ax1, label='Total Tests')
ax1.set_xlabel('Date')
ax1.set_ylabel('Total Tests', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create second axis for positive rate
ax2 = ax1.twinx()
sns.lineplot(data=global_daily_testing, x='date', y='positive_rate', color='red', ax=ax2, label='Positive Rate')
ax2.set_ylabel('Positive Rate (%)', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Adjust the y-axis limits for positive rate to 100%
ax2.set_ylim(0,100)

# Add title and legend
plt.title('Global Total Tests and Positive Rate Over Time')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)

plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Activity 6: In-Depth Country Analysis
# In-Depth Country Analysis Conducting an in-depth examination of specific countries, understanding the correlation between cases and deaths globally, and exploring continental variations in case distribution.

# %% [markdown]
# ## Visualize the total COVID-19 cases by country
# 1. Visualize the total COVID-19 cases and deaths over time for a specific country.

# %%
country_name = 'India'   # ← change this to your desired country

# Filter dataset for that country
df_country = df[df['location'] == country_name].copy()

# Create a dual-axis plot for better comparison
fig, ax1 = plt.subplots(figsize=(15, 7))

# Plot total cases (left axis)
sns.lineplot(data=df_country, x='date', y='total_cases', color='blue', ax=ax1, label='Total Cases')
ax1.set_xlabel('Date')
ax1.set_ylabel('Total Cases', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create second axis for total deaths
ax2 = ax1.twinx()
sns.lineplot(data=df_country, x='date', y='total_deaths', color='red', ax=ax2, label='Total Deaths')
ax2.set_ylabel('Total Deaths', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add title
plt.title(f'Total COVID-19 Cases and Deaths Over Time in {country_name}')

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# Adjust the y-axis limits for total_deaths to be closer to total_cases
# This will make the total_deaths trend appear very flat due to the difference in magnitude.
ax2.set_ylim(ax1.get_ylim()[0]/20,ax1.get_ylim()[1]/20)

plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize by user selection
# 2. Get user input for the country and metric (total_cases or total_deaths) and plot a line chart for the user selected values.

# %%
country_name = ""
while country_name.lower() not in [loc.lower() for loc in df['location'].unique()]:
    country_name=input("Enter the country name: ")
    if country_name.lower() not in [loc.lower() for loc in df['location'].unique()]:
        print(f"Invalid country name: {country_name}. Please enter a valid country from the dataset.")

# Find the correctly cased country name from the unique locations
correct_country_name = [loc for loc in df['location'].unique() if loc.lower() == country_name.lower()][0]

# Filter dataset for that country
df_country = df[df['location'] == correct_country_name].copy()

# Create a dual-axis plot for better comparison
fig, ax1 = plt.subplots(figsize=(15, 7))

# Plot total cases (left axis)
sns.lineplot(data=df_country, x='date', y='total_cases', color='blue', ax=ax1, label='Total Cases')
ax1.set_xlabel('Date')
ax1.set_ylabel('Total Cases', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create second axis for total deaths
ax2 = ax1.twinx()
sns.lineplot(data=df_country, x='date', y='total_deaths', color='red', ax=ax2, label='Total Deaths')
ax2.set_ylabel('Total Deaths', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add title
plt.title(f'Total COVID-19 Cases and Deaths Over Time in {correct_country_name}')

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')
ax2.legend(lines + lines2, labels + labels2, loc='upper left')

# Adjust the y-axis limits for total_deaths to be closer to total_cases
# This will make the total_deaths trend appear very flat due to the difference in magnitude.
ax2.set_ylim(ax1.get_ylim()[0]/20, ax1.get_ylim()[1]/20)

plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Enter the country name: singapore

# %% [markdown]
# ## Visualize distribution of total cases by different continents
# 3. Analyze the distribution of total cases across different continents using a box plot.

# %%
plt.figure(figsize=(10,7.5))
sns.boxplot(data=df, x='continent', y='total_cases', hue='continent', palette='Set2')

# 3️⃣ Add titles and labels
plt.title('Distribution of Total COVID-19 Cases by Continent')
plt.xlabel('Continent')
plt.ylabel('Total Cases')
plt.yscale('log')  # Optional: use log scale if values vary widely
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize monthly trend of new COVID-19 cases by user selection
# 4. Visualize the Year wise monthly trend of new COVID-19 cases for user selected country.

# %%
country_name = ""
while country_name.lower() not in [loc.lower() for loc in df['location'].unique()]:
    country_name=input("Enter the country name: ")
    if country_name.lower() not in [loc.lower() for loc in df['location'].unique()]:
        print(f"Invalid country name: {country_name}. Please enter a valid country from the dataset.")

# Find the correctly cased country name from the unique locations
correct_country_name = [loc for loc in df['location'].unique() if loc.lower() == country_name.lower()][0]

# Filter dataset for that country
df_country = df[df['location'] == correct_country_name].copy()

df_monthly_cases = df_country.groupby(['year','month'])['new_cases'].sum().reset_index()

# Create a combined year-month string for the x-axis and format it to show short month names
df_monthly_cases['year_month'] = pd.to_datetime(df_monthly_cases['year'].astype(str) + '-' + df_monthly_cases['month'].astype(str) + '-01').dt.strftime('%b')

plt.figure(figsize=(15,7))
# Use hue='year' to plot different colored lines for each year
sns.lineplot(data=df_monthly_cases, x='year_month', y='new_cases', hue='year', palette='tab10', linewidth=2)
plt.title(f'Year-wise Monthly Trend of New COVID-19 Cases in {correct_country_name}')
plt.xlabel('Month')
plt.ylabel('New Cases')
# Set x-ticks to show only the month numbers for clarity on a yearly trend plot
plt.xticks(rotation=45)
plt.legend(title='Year', loc='upper left') # Place legend in upper left
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# Enter the country name: singapore

# %% [markdown]
# # Activity 7: Additional Insights
# Additional Insights Extracting additional insights, examining the influence of external factors, and evaluating regional disparities for a holistic understanding of the COVID-19 landscape.

# %% [markdown]
# ## Visualize the fatality rate over time
# 1. Visualize the fatality rate (total deaths / total cases) over time globally.

# %% [markdown]
# ### Prepare data for global analysis
# Calculates the daily global fatality rate by dividing total deaths by total cases.

# %%
daily_global = df.groupby('date')[['total_cases', 'total_deaths']].sum().reset_index()
daily_global['fatality_rate'] = daily_global['total_deaths'] / daily_global['total_cases']
display(daily_global.head())
# Out:
#         date   total_cases  total_deaths  fatality_rate
# 0 2020-01-01  1.372484e+07  1.739087e+05       0.012671
# 1 2020-01-02  1.372484e+07  1.739087e+05       0.012671
# 2 2020-01-03  1.688155e+09  2.139077e+07       0.012671
# 3 2020-01-04  1.626393e+09  2.139077e+07       0.013152
# 4 2020-01-05  1.633256e+09  2.095602e+07       0.012831

# %%
# Plot fatality rate over time by line plot
plt.figure(figsize=(12,6))
sns.lineplot(data=daily_global, x='date', y='fatality_rate', color='red', linewidth=2)

plt.title('Global COVID-19 Fatality Rate Over Time')
plt.xlabel('Date')
plt.ylabel('Fatality Rate')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Explore positivity rate
# 2. Explore positivity rate (total_cases/ total tests) verses total tests conducted to analyse testing effectiveness use x axis as logarithmic scale for better visualization.

# %% [markdown]
# ### Prepare data for positivity rate
# Calculates the positivity rate by dividing total cases by total tests.

# %%
df['positivity_rate'] = df['total_cases'] / df['total_tests']
df.head()
# Out:
#   iso_code continent     location       date   total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-01-03  6.862419e+06        0.0
# 1      AFG      Asia  Afghanistan 2020-01-04  6.862419e+06        0.0
# 2      AFG      Asia  Afghanistan 2020-01-05  6.862419e+06        0.0
# 3      AFG      Asia  Afghanistan 2020-01-06  6.862419e+06        0.0
# 4      AFG      Asia  Afghanistan 2020-01-07  6.862419e+06        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0         9409.255662  86954.368292         0.0            83.807025  ...
# 1         9409.255662  86954.368292         0.0            83.807025  ...
# 2         9409.255662  86954.368292         0.0            83.807025  ...
# 3         9409.255662  86954.368292         0.0            83.807025  ...
# 4         9409.255662  86954.368292         0.0            83.807025  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
# Create scatter plot
plt.figure(figsize=(15,6))
sns.scatterplot(data=df, x='total_tests', y='positivity_rate', alpha=0.6)

# Set x-axis to logarithmic scale
plt.xscale('log')

# Add titles and labels
plt.title('Positivity Rate vs Total Tests Conducted')
plt.xlabel('Total Tests Conducted (log scale)')
plt.ylabel('Positivity Rate')
plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyze fatality rate with smoking
# 3. Analyze fatality rate and its relationship with smoking (Use male_smokers and female_smokers columns)

# %% [markdown]
# ### Prepares data for analyzing the relationship between fatality rate and smoking
# Calculate data for analyzing the relationship between fatality rate and smoking by removing rows with missing values in relevant columns and calculating the fatality rate.

# %%
# Create a new DataFrame with relevant columns and calculate fatality rate
df_fatality_smokers = df[['total_cases', 'total_deaths', 'male_smokers', 'female_smokers']].copy()
df_fatality_smokers['fatality_rate'] = df_fatality_smokers['total_deaths'] / df_fatality_smokers['total_cases']
df_fatality_smokers.head()
# Out:
#     total_cases  total_deaths  male_smokers  female_smokers  fatality_rate
# 0  6.862419e+06  86954.368292     32.910129       10.793543       0.012671
# 1  6.862419e+06  86954.368292     32.910129       10.793543       0.012671
# 2  6.862419e+06  86954.368292     32.910129       10.793543       0.012671
# 3  6.862419e+06  86954.368292     32.910129       10.793543       0.012671
# 4  6.862419e+06  86954.368292     32.910129       10.793543       0.012671

# %%
# Create scatter plots
plt.figure(figsize=(15,6))

# Male smokers
plt.subplot(1,2,1)
sns.scatterplot(data=df_fatality_smokers, x='male_smokers', y='fatality_rate', alpha=0.5)
sns.regplot(data=df_fatality_smokers, x='male_smokers', y='fatality_rate', scatter=False, color='green')
plt.title('Fatality Rate vs Male Smokers')
plt.xlabel('% Male Smokers')
plt.ylabel('Fatality Rate')

# Female smokers
plt.subplot(1,2,2)
sns.scatterplot(data=df_fatality_smokers, x='female_smokers', y='fatality_rate', alpha=0.5)
sns.regplot(data=df_fatality_smokers, x='female_smokers', y='fatality_rate', scatter=False, color='red')
plt.title('Fatality Rate vs Female Smokers')
plt.xlabel('% Female Smokers')
plt.ylabel('Fatality Rate')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Create a heatmap
# 4. Create a heatmap to analyze the relationship between hospital beds per thousand and fatality rate.

# %% [markdown]
# ### Prepares the data for analyzing the relationship between hospital beds and fatality rate
# Calculate data for analyzing the relationship between hospital beds and fatality rate by removing rows with missing values in relevant columns and calculating the fatality rate.

# %%
# Create new dataframe for analyzing the relationship between hospital beds and fatality rate
df_fatality_rship = df[['total_cases', 'total_deaths', 'hospital_beds_per_thousand']].copy()
# Calculate fatality rate
df_fatality_rship['fatality_rate'] = df_fatality_rship['total_deaths'] / df_fatality_rship['total_cases']
df_fatality_rship.head()
# Out:
#     total_cases  total_deaths  hospital_beds_per_thousand  fatality_rate
# 0  6.862419e+06  86954.368292                         0.5       0.012671
# 1  6.862419e+06  86954.368292                         0.5       0.012671
# 2  6.862419e+06  86954.368292                         0.5       0.012671
# 3  6.862419e+06  86954.368292                         0.5       0.012671
# 4  6.862419e+06  86954.368292                         0.5       0.012671

# %%
# Create a correlation matrix
corr_matrix = df_fatality_rship[['fatality_rate','hospital_beds_per_thousand']].corr()

# Plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation: Hospital Beds per Thousand vs Fatality Rate')
plt.show()
